# %%
import sys
sys.path.append('..')
import from_Citrine

# %%
api_key = None        # Set your Citrine API key here. If set as an environment variable 'CITRINE_KEY', set it to 'None'

# %%
c = from_Citrine.CitrineDataRetrieval(api_key, contributor='Lany', term='ag2ba')     # Retrive data from the Citrine database that is contributed by "Lany" and that contain the term "ag2ba" in any field of the filtered records

# %%
c.to_pandas()  # Converts the search results into a Pandas dataframe. Records with same indexes indicate different various measurements of the same sample
# Out:
#      data_set_id material.chemicalFormula  \
# Hit
# 1         149854                  Ag2BaS2
# 1         149854                  Ag2BaS2
# 1         149854                  Ag2BaS2
# 1         149854                  Ag2BaS2
# 2         149854                 Ag2BaTe2
# 2         149854                 Ag2BaTe2
# 2         149854                 Ag2BaTe2
# 2         149854                 Ag2BaTe2
# 3         149854                  Ag2BaS2
# 3         149854                  Ag2BaS2
# 3         149854                  Ag2BaS2
# 3         149854                  Ag2BaS2
# 4         149854                 Ag2BaTe2
# 4         149854                 Ag2BaTe2
# 4         149854                 Ag2BaTe2
# 4         149854                 Ag2BaTe2
# 5         149854                Ag2BaGeS4
# 5         149854                Ag2BaGeS4
# 5         149854                Ag2BaGeS4
# 5         149854                Ag2BaGeS4
# 6         149854                Ag2BaS4Sn
# ...
