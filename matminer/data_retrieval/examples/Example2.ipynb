# %% [markdown]
# ## Citrine data retrieval example

# %% [markdown]
# This notebook demonstrates use of the code 'retrieve_Citrine.py' in retrieving data from various datasets collected by Citrine Informatics at http://citrination.com/, and output it in the form of a Pandas dataframe. In this example, we query the Citrine API to retrieve all the data on the semiconductor material GaN contributed by 'OQMD' (http://oqmd.org/) to Citrine.

# %%
from matminer.data_retrieval.retrieve_Citrine import CitrineDataRetrieval

# %%
api_key = None     # Set your Citrine API key here. If set as an environment variable 'CITRINE_KEY', set it to 'None'

# %% [markdown]
# Create an adapter to the Citrine Database.

# %%
c = CitrineDataRetrieval(api_key)
df = c.get_dataframe(contributor='OQMD', formula='GaN')
df
# Out:
#         data_set_id material.chemicalFormula  \
# sample
# 1              1183                      GaN
# 2              1178                      GaN
# 3              1182                      GaN
# 4              1175                      GaN
# 5              1165                      GaN
# 6              1165                   Mn3GaN
# 7              1152                    CaGaN
# 8              1166                   Nd3GaN
# 9            113929                    CaGaN
# 10           113921                    CaGaN
# 11             1163                   Cr2GaN
# 12             1167                   Cr3GaN
# 13             1158                   ZnGaNO
# 14             1167                   ZnGaNO
# 15             1167                   ZnGaNO
# 16             1177                     GaN3
# 17             1179                     GaN3
# 18             1174                     GaN3
# 19             1186                     GaN3
# 20             1156                  GaH3NF3
# 21             1165                 Ba2GaGeN
# 22             1169                  GaH4NF4
# 23             1169                 Sr2GaGeN
# 24             1158                 ZnGa3N3O
# 25             1159                  Sr3GaN3
# 26             1159                  Sr6GaN5
# 27             1159                  GaN5O14
# 28             1168                  GaN5O14
# 29             1171                  Ca6GaN5
# 30             1171                  Li3GaN2
# 31             1157                  La2GaN3
#
#                                        material.condition Band gap  \
# sample
# 1       [{u'scalar': [{u'value': u'334755'}], u'name':...     1.99
# 2       [{u'scalar': [{u'value': u'317241'}], u'name':...     0.00
# 3       [{u'scalar': [{u'value': u'331269'}], u'name':...     0.72
# 4       [{u'scalar': [{u'value': u'306699'}], u'name':...     0.00
# 5       [{u'scalar': [{u'value': u'97043'}], u'name': ...     2.09
# 6       [{u'scalar': [{u'value': u'15510'}], u'name': ...     0.00
# 7       [{u'scalar': [{u'value': u'2044'}], u'name': u...     0.00
# 8       [{u'scalar': [{u'value': u'17258'}], u'name': ...     0.00
# 9       [{u'scalar': [{u'value': u'2044'}], u'name': u...     0.00
# 10      [{u'scalar': [{u'value': u'2044'}], u'name': u...     0.00
# 11      [{u'scalar': [{u'value': u'51566'}], u'name': ...     0.00
# 12      [{u'scalar': [{u'value': u'647109'}], u'name':...     0.00
# 13      [{u'scalar': [{u'value': u'20342'}], u'name': ...     0.53
# 14      [{u'scalar': [{u'value': u'20341'}], u'name': ...     0.00
# 15      [{u'scalar': [{u'value': u'20343'}], u'name': ...     0.00
# 16      [{u'scalar': [{u'value': u'313393'}], u'name':...     0.00
# 17      [{u'scalar': [{u'value': u'323106'}], u'name':...     0.00
# 18      [{u'scalar': [{u'value': u'302851'}], u'name':...     0.00
# 19      [{u'scalar': [{u'value': u'347592'}], u'name':...     0.00
# 20      [{u'scalar': [{u'value': u'15761'}], u'name': ...     5.79
# 21      [{u'scalar': [{u'value': u'15061'}], u'name': ...     0.00
# 22      [{u'scalar': [{u'value': u'25250'}], u'name': ...     5.78
# 23      [{u'scalar': [{u'value': u'26877'}], u'name': ...     0.00
# 24      [{u'scalar': [{u'value': u'20344'}], u'name': ...     0.33
# 25      [{u'scalar': [{u'value': u'24307'}], u'name': ...     0.73
# 26      [{u'scalar': [{u'value': u'24308'}], u'name': ...     0.43
# 27      [{u'scalar': [{u'value': u'24155'}], u'name': ...     2.03
# 28      [{u'scalar': [{u'value': u'24154'}], u'name': ...     1.90
# 29      [{u'scalar': [{u'value': u'6342'}], u'name': u...     0.79
# 30      [{u'scalar': [{u'value': u'30294'}], u'name': ...     2.73
# 31      [{u'scalar': [{u'value': u'20275'}], u'name': ...     1.95
#
#        Formation energy Stability (energy relative to convex hull)  \
# sample
# 1                -0.594                                     -0.584
# 2                 0.355                                      0.950
# 3                -0.116                                      0.479
# 4                 1.026                                      1.620
# 5                -0.593                                      0.001
# 6                -0.346                                     -0.088
# 7                -0.813                                     -0.040
# 8                 0.902                                      1.730
# 9                -0.813                                     -0.040
# 10               -0.813                                     -0.040
# 11               -0.347                                      0.037
# 12               -0.297                                      0.028
# 13               -1.081                                      0.060
# 14               -1.059                                      0.022
# 15               -1.062                                      0.019
# 16                2.396                                      0.701
# 17                1.695                                      1.992
# 18                2.461                                      0.766
# 19                2.425                                      0.730
# 20               -1.778                                     -0.036
# 21               -0.633                                     -0.036
# 22               -1.810                                      0.009
# 23               -0.712                                     -0.045
# 24               -0.816                                      0.052
# 25               -0.738                                     -0.049
# 26               -0.690                                      0.005
# 27               -0.693                                      0.007
# 28               -0.690                                      0.003
# 29               -0.909                                     -0.026
# 30               -0.617                                     -0.130
# 31               -1.171                                     -0.012
#
#                                     measurement.condition  \
# sample
# 1       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 2       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 3       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 4       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 5       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 6       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 7       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 8       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 9       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 10      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 11      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 12      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 13      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 14      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 15      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 16      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 17      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 18      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 19      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 20      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 21      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 22      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 23      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 24      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 25      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 26      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 27      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 28      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 29      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 30      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 31      [{u'units': u'KPPRA', u'scalar': [{u'value': u...
#
#        measurement.dataType measurement.method  \
# sample
# 1             Computational  VASP with PAW/PBE
# 2             Computational  VASP with PAW/PBE
# 3             Computational  VASP with PAW/PBE
# 4             Computational  VASP with PAW/PBE
# 5             Computational  VASP with PAW/PBE
# 6             Computational  VASP with PAW/PBE
# 7             Computational  VASP with PAW/PBE
# 8             Computational  VASP with PAW/PBE
# 9             Computational  VASP with PAW/PBE
# 10            Computational  VASP with PAW/PBE
# 11            Computational  VASP with PAW/PBE
# 12            Computational  VASP with PAW/PBE
# 13            Computational  VASP with PAW/PBE
# 14            Computational  VASP with PAW/PBE
# 15            Computational  VASP with PAW/PBE
# 16            Computational  VASP with PAW/PBE
# 17            Computational  VASP with PAW/PBE
# 18            Computational  VASP with PAW/PBE
# 19            Computational  VASP with PAW/PBE
# 20            Computational  VASP with PAW/PBE
# 21            Computational  VASP with PAW/PBE
# 22            Computational  VASP with PAW/PBE
# 23            Computational  VASP with PAW/PBE
# 24            Computational  VASP with PAW/PBE
# 25            Computational  VASP with PAW/PBE
# 26            Computational  VASP with PAW/PBE
# 27            Computational  VASP with PAW/PBE
# 28            Computational  VASP with PAW/PBE
# 29            Computational  VASP with PAW/PBE
# 30            Computational  VASP with PAW/PBE
# 31            Computational  VASP with PAW/PBE
#
#                                     measurement.reference  \
# sample
# 1       [{u'url': u'http://oqmd.org/materials/entry/33...
# 2       [{u'url': u'http://oqmd.org/materials/entry/31...
# 3       [{u'url': u'http://oqmd.org/materials/entry/33...
# 4       [{u'url': u'http://oqmd.org/materials/entry/30...
# 5       [{u'url': u'http://oqmd.org/materials/entry/97...
# 6       [{u'url': u'http://oqmd.org/materials/entry/15...
# 7       [{u'url': u'http://oqmd.org/materials/entry/20...
# 8       [{u'url': u'http://oqmd.org/materials/entry/17...
# 9       [{u'url': u'http://oqmd.org/materials/entry/20...
# 10      [{u'url': u'http://oqmd.org/materials/entry/20...
# 11      [{u'url': u'http://oqmd.org/materials/entry/51...
# 12      [{u'url': u'http://oqmd.org/materials/entry/64...
# 13      [{u'url': u'http://oqmd.org/materials/entry/20...
# 14      [{u'url': u'http://oqmd.org/materials/entry/20...
# 15      [{u'url': u'http://oqmd.org/materials/entry/20...
# 16      [{u'url': u'http://oqmd.org/materials/entry/31...
# 17      [{u'url': u'http://oqmd.org/materials/entry/32...
# 18      [{u'url': u'http://oqmd.org/materials/entry/30...
# 19      [{u'url': u'http://oqmd.org/materials/entry/34...
# 20      [{u'url': u'http://oqmd.org/materials/entry/15...
# 21      [{u'url': u'http://oqmd.org/materials/entry/15...
# 22      [{u'url': u'http://oqmd.org/materials/entry/25...
# 23      [{u'url': u'http://oqmd.org/materials/entry/26...
# 24      [{u'url': u'http://oqmd.org/materials/entry/20...
# 25      [{u'url': u'http://oqmd.org/materials/entry/24...
# 26      [{u'url': u'http://oqmd.org/materials/entry/24...
# 27      [{u'url': u'http://oqmd.org/materials/entry/24...
# 28      [{u'url': u'http://oqmd.org/materials/entry/24...
# 29      [{u'url': u'http://oqmd.org/materials/entry/63...
# 30      [{u'url': u'http://oqmd.org/materials/entry/30...
# 31      [{u'url': u'http://oqmd.org/materials/entry/20...
#
#                                            property.units
# sample
# 1       {u'Formation energy': u'eV/atom', u'Band gap':...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# 30                                                    NaN
# 31                                                    NaN

# %% [markdown]
# In the dataframe above, the search query results in 31 samples/hits from the Citrine API, each with 3 properties - band gap, formation energy, and energy relative to convex hull.

# %% [markdown]
# Note: the above query also pulls samples that also contain the chemical formula of 'GaN', such as La2GaN3, and not just the compound 'GaN'. To filter results only for the compound 'GaN', we run the following query on the dataframe,

# %%
df.loc[df['material.chemicalFormula'] == 'GaN']
# Out:
#         data_set_id material.chemicalFormula  \
# sample
# 1              1183                      GaN
# 2              1178                      GaN
# 3              1182                      GaN
# 4              1175                      GaN
# 5              1165                      GaN
#
#                                        material.condition Band gap  \
# sample
# 1       [{u'scalar': [{u'value': u'334755'}], u'name':...     1.99
# 2       [{u'scalar': [{u'value': u'317241'}], u'name':...     0.00
# 3       [{u'scalar': [{u'value': u'331269'}], u'name':...     0.72
# 4       [{u'scalar': [{u'value': u'306699'}], u'name':...     0.00
# 5       [{u'scalar': [{u'value': u'97043'}], u'name': ...     2.09
#
#        Formation energy Stability (energy relative to convex hull)  \
# sample
# 1                -0.594                                     -0.584
# 2                 0.355                                      0.950
# 3                -0.116                                      0.479
# 4                 1.026                                      1.620
# 5                -0.593                                      0.001
#
#                                     measurement.condition  \
# sample
# 1       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 2       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 3       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 4       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
# 5       [{u'units': u'KPPRA', u'scalar': [{u'value': u...
#
#        measurement.dataType measurement.method  \
# sample
# 1             Computational  VASP with PAW/PBE
# 2             Computational  VASP with PAW/PBE
# 3             Computational  VASP with PAW/PBE
# 4             Computational  VASP with PAW/PBE
# 5             Computational  VASP with PAW/PBE
#
#                                     measurement.reference  \
# sample
# 1       [{u'url': u'http://oqmd.org/materials/entry/33...
# 2       [{u'url': u'http://oqmd.org/materials/entry/31...
# 3       [{u'url': u'http://oqmd.org/materials/entry/33...
# 4       [{u'url': u'http://oqmd.org/materials/entry/30...
# 5       [{u'url': u'http://oqmd.org/materials/entry/97...
#
#                                            property.units
# sample
# 1       {u'Formation energy': u'eV/atom', u'Band gap':...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
